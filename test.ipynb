# %%
import sys
print(sys.executable)
# Out:
# c:\Users\carro\anaconda3\envs\project\python.exe

# %%
import sys
print(sys.version)
# Out:
# 3.9.25 (main, Nov  3 2025, 22:44:01) [MSC v.1929 64 bit (AMD64)]
